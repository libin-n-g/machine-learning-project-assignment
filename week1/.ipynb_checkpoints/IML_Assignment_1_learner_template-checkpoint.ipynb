# %% [markdown]
# # Week1: Linear Models

# %% [markdown]
# # Objective
#
# This homework sheet will help reviewing the basic concepts associated with linear regression models. Please review the lectures, suggested readings, and additional resources __before__ getting started on the HW

# %% [markdown]
# **Some questions in this assignment will require you to conduct independent research beyond the material covered in the recorded content.**

# %% [markdown]
# **Questions**
#
# This homework is divided into two main parts. First, a conceptual component will review the basic concepts related to linear models. The second part of the homework is mostly intended to be a brief introduction to fitting and analyzing linear models in Python. Several of these questions are modified from James et al. (2021).

# %% [markdown]
# Marks Distribution

# %% [markdown]
# | Question      | Marks |
# | ----------- | ----------- |
# | 1     | 1      |
# | 2a    | 0.25     |
# | 2b    | 0.25      |
# | 2c    | 0.25      |
# | 2d     | 0.25      |
# | 3a     | 0.25     |
# | 3b    | 0.25     |
# | 3c     | 0.25     |
# | 3d    | 0.25   |
# | 4a.i    | 0.25      |
# | 4a.ii    | 0.25     |
# | 4a.iii     | 0.25      |
# | 4a.iv    | 0.50      |
# | 4a.v     | 0.25      |
# | 4a.vi    | 0.50      |
# | 4b    | 0.50     |
# | 4c    | 0.50      |
# | 5a     | 0.25      |
# | 5b    | 0.25      |
# | 5c.i    | 0.25      |
# | 5c.ii    | 0.25      |
# | 5c.iii    | 0.25      |
# | 5d    | 0.25      |
# | 5e    | 0.25      |
# | 5f    | 0.25     |
# | 6a    | 0.25      |
# | 6b    | 0.25      |
# | 6c    | 0.25      |
# | 6d     | 0.25      |
# | 6e    | 0.25      |
# | 6f    | 0.25      |
# | 6g     | 0.50      |
# | 6h    | 0.50      |
# | 6i     | 0.50      |
# | 6j     | 0.50      |
# | 7a    | 0.25      |
# | 7b    | 0.50      |
# | 7c    | 0.50      |
# | 7d     | 0.25      |
# | 7e    | 0.25      |
# | 7f    | 0.25      |
# | 7g     | 0.50      |
# | 8     | 1      |

# %% [markdown]
# The following website has access to the relevant datasets from the recommended textbook: https://book.huihoo.com/introduction-to-statistical-learning/data.html

# %% [markdown]
# # Conceptual

# %% [markdown]
# ## Question 1

# %% [markdown]
# Describe the null hypotheses to which the _p_-values given in the table (see below). Explain what conclusions you can draw based on these p-values. Your explanation should be phrased in terms of sales, TV, radio, and newspaper, rather than in terms of the coefficients of the linear model.
#
# |  | Coefficient | Std. error | t-statistics | p-value |
# |---|:---:|:---:|:---:|:---:|
# | Intercept | 2.939 | 0.3119 | 9.42 | <0.0001 |
# | TV | 0.046 | 0.0014 | 32.81 | <0.0001 |
# | Radio | 0.189 | 0.0086 | 21.89 | <0.0001 |
# | Newspaper | -0.001 | 0.0059 | -0.18 | 0.8599 |

# %% [markdown]
# **Null hypothesis** here is that there is no relationship between the considered variable (Intercept, TV, Radio, Newspaper given by X) and Sales (Y). In other words it means we have $\hat{β}_{Intercept} = 0 $ for first row,  $\hat{β}_{TV} = 0 $ for second row,  $\hat{β}_{Radio} = 0 $ for third row, $\hat{β}_{Newspaper} = 0 $ for fourth row as Null Hypothesis.
#
#
# ##### **Conclusions**
# Intercept, TV, Radio seems to have a significant effect on Sales. But Newspaper seems to be having almost no effect on sales as the p value is much higher. Hence advertisement in TV and radio seems to increase the sales significantly while Newspaper advertisement seems to have no effect in sales. This may or may not be true as we have assumed that the variable are independent (no interactions) as we use multiple regression model to find the coefficients. If the assumptions of the model is wrong, then the results will obviously can be wrong.

# %% [markdown]
# ## Question 2
#
# Assume that you collected a dataset of 100 observations containing a single predictor and a quantitative response. Then, you decided to fit a
#
# (i) linear regression model to the data, as well as a separate
#
# (ii) cubic regression, i.e. $Y = β_{0} + β_{1}X^{1} + β_{2}X^{2} + β_{3}X^{3} + ϵ$

# %% [markdown]
# ### a) Suppose that the true relationship between $X$ and $Y$ is linear, i.e. $Y = β_{0} + β_{1}X + ϵ$. Consider the training residual sum of squares (_RSS_) for the linear regression, and also the training _RSS_ for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer

# %% [markdown]
# We can expect the cubic regression to show less training RSS. This is because cubic regression has higher complexity and very easily result in overfitting. That is, cubic regression result in model with very high variance and low bias.

# %% [markdown]
# ### b) Answer part (a) using the test _RSS_ rather than training _RSS_.

# %% [markdown]
# We would expect linear regression to have less test RSS. This is because linear regression is less complex and will result in model having less variance compared to cubic regression. Also note that we have 100 observations with just one predictor ($ n >> p $). This usually means linear regression will learn the true linear relationship between $X$ and $Y$ with good efficiency. This will result in less bias as true model is very close to predicted model resulting in very less test RSS.

# %% [markdown]
# ### c) Suppose that the true relationship between $X$ and $Y$ is not linear. However, we don’t know how far it is from linear. Consider the training _RSS_ for the linear regression, and also the training _RSS_ for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.

# %% [markdown]
# In general, I would expect cubic regression to show lower training RSS. This is because, when we have more complex the model, we get more variance. Thus high variance model will result in overfitting more training observations resulting in less training RSS.

# %% [markdown]
# ### d) Answer (c) using test _RSS_ rather than training _RSS._

# %% [markdown]
# In general, linear model will have more bias and less variance, while cubic regression will have less bias and more variance. But considering that the true relationship between $X$ and $Y$ is not linear, We can say the model which is closer to true relationship have less test RSS. If the model is too away from linear relationship, then linear model will not be able to learn the general pattern in the dataset resulting in errors due to high bias of linear model. Similarly if the true model is very close to linear model, then high variance of cubic model will result in high amount of error in test RSS. Hence there is not enough information to answer the question.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### a) Discuss the implications that uncertainty in $X$ would have on parameter estimates based on linear regression models. Should we care about error in $X$ when fitting OLS regressions?

# %% [markdown]
# Error in X will cause Regression dilution where the parameter estimates are underestimated. As Uncertainty in $X$ increases, the relationship between $X$ and $Y$ becomes weak and hence slope(parameter) decreses. Therefore the $ \hat{\beta}_1 $ value decreases from the true value resulting in Regression dilution. Hence we should care about error in $X$ as more error means highly underestimated value of $ \hat{\beta}_1 $ . Another issue efficiency of the estimators will be reduced because of this. Measurement error in X can lead to incorrect conclusions in hypothesis testing because the regression dilution causes the predicted parameters to go to zero.

# %% [markdown]
# ### b) Provide a brief discussion on the concept of regression dilution.

# %% [markdown]
# Regression dilution occurs when there is measurement error in the independent variable (X) in a regression model. This error can lead to underestimation of the true relationship between X and the dependent variable (Y). This attenuation of the slope coefficient is due to the fact that the measured values of X are imperfectly correlated with the true values of X, leading to an underestimate of the true effect of X on Y.To mitigate the effects of regression dilution, researchers can use methods such as instrumental variables, measurement error models, or robust standard errors, depending on the nature of the measurement error and the research question at hand.
#
# The least squares estimates in ordinary least squares (OLS) for the model $ y = \beta_1 X + \beta_0 $ can be expressed as:
#
# $ \hat{\beta}_1 = \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sum_{i=1}^{n} (x_i - \bar{x})^2} = \frac{Cov(X,Y)}{Var(X)}$
#
# $ \hat{\beta}_0 = \bar{y} - \hat{\beta}_1 \bar{x} $
#
# Where:
# - $ \hat{\beta}_1 $ is the estimated intercept,
# - $ \hat{\beta}_0 $ is the estimated slope,
# - $ x_i $ and $ y_i $ are the observed values,
# - $ \bar{x} $ and $ \bar{y} $ are the means of the observed values.
#
# Suppose the $\widetilde{X} = X + w$. where w is the error in $X$. On simplification we can show that the $ \hat{\beta}_1^{'} = \hat{\beta}_1 \frac{Var(X)}{Var(X) + Var(w)} $. Where we assume $w$ and $X$ are independent and $E[w] = 0$ . We can see that the slope becomes low as we error variance increases. This behaviour is called regression dilution.

# %% [markdown]
# ### c) Are there any linear regression models that account for uncertainty in $X$ and $Y$? Please do some independent research and cite your sources.

# %% [markdown]
# - Errors-in-variables models or measurement error models are regression models that account for measurement errors in the independent variables. In contrast, standard regression models assume that those regressors have been measured exactly, or observed without error; as such, those models account only for errors in the dependent variables, or responses Reference: https://en.wikipedia.org/wiki/Errors-in-variables_models
# - Total Least Squares Regression (TLS): TLS is a regression technique that minimizes the perpendicular distances from the data points to the regression line, rather than just the vertical distances as in ordinary least squares (OLS). This method accounts for errors in both X and Y variables. Ref: https://en.wikipedia.org/wiki/Total_least_squares
# - Deming regression is an errors-in-variables model that tries to find the line of best fit for a two-dimensional data set. Ref: https://en.wikipedia.org/wiki/Deming_regression

# %% [markdown]
# ### d) Distinguish between least squares and maximum likelihood in the context of linear regression models

# %% [markdown]
# Least squares is a specific method for estimating the parameters of a linear regression model by minimizing the sum of squared residuals, while maximum likelihood is a more general statistical approach that aims to find the parameter values that make the observed data most likely under the assumed model.
#
# In the context of linear regression models, least squares and maximum likelihood are two different methods used to estimate the parameters of the model.
#
# **Least Squares (LS)**:
# - **Objective**: Minimizes the sum of the squared differences between the observed values of the dependent variable (Y) and the values predicted by the linear regression model.
# - **Estimation**: Estimates the parameters (coefficients) of the regression model that minimize the sum of squared residuals.
# - **Advantages**: Simple to implement, computationally efficient, and has closed-form solutions for parameter estimation.
# - **Disadvantages**: Assumes normally distributed errors, sensitive to outliers, and does not provide a measure of uncertainty in the parameter estimates.
#
# **Maximum Likelihood Estimation (MLE)**:
# - **Objective**: Maximizes the likelihood function, which measures the probability of observing the given data under the assumed statistical model.
# - **Estimation**: Estimates the parameters of the regression model that maximize the likelihood function, making the observed data most probable under the assumed model.
# - **Advantages**: Provides a more flexible framework that can accommodate different error distributions, provides measures of uncertainty (standard errors) for the parameter estimates, and allows for hypothesis testing using likelihood ratio tests.
# - **Disadvantages**: Can be computationally intensive, especially for complex models and large datasets, and requires specifying a probability distribution for the errors.

# %% [markdown]
# # Applied
#
# Please note that some of the questions outlined below make suggestions on potential functions to be used in the answers. Feel free to use any other function. These are just a reference.

# %% [markdown]
# ## Question 4
#
# This question involves the use of simple linear regression on the Auto data set.
#
# ### a) Use the " OLS() function " from " Statsmodels " library to perform a simple linear regression with " mpg " as the response and " horsepower" as the predictor. Use the "summary()" function to print the results. Then, answer the questions below:
#
# Reference to Statsmodels library and ols :
#
# https://www.statsmodels.org/dev/generated/statsmodels.regression.linear_model.OLS.html#generated-statsmodels-regression-linear-model-ols--page-root

# %%
#IMPORT LIBRARIES
import statsmodels.api as sm
import numpy as np
import pandas as pd

# %%
#READ AUTO.CSV DATASET
df = pd.read_csv('Auto.csv')

# %% [markdown]
# #### Exploring the data and its types.

# %%
#PERFORM PRE PROCESSING OF DATA IF REQUIRED ( OBSERVE THE DATASET AND ITS VALUES CAREFULLY)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   397.000000  397.000000    397.000000        397   397.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.515869    5.458438    193.532746        NaN  2970.261965
# std       7.825804    1.701577    104.379583        NaN   847.904119
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.000000        NaN  2223.000000
# 50%      23.000000    4.000000    146.000000        NaN  2800.000000
# 75%      29.000000    8.000000    262.000000        NaN  3609.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration        year      origin        name
# count     397.000000  397.000000  397.000000         397
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
#  - We need to Convert horsepower to numenric value.

# %%
df_processed = df.copy()
df_processed['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
#  - Cheking if there is any rows which we were not able to convert types.

# %%
df[df_processed['horsepower'].isna()]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?    2046          19.0    71
# 126  21.0          6         200.0          ?    2875          17.0    74
# 330  40.9          4          85.0          ?    1835          17.3    80
# 336  23.6          4         140.0          ?    2905          14.3    80
# 354  34.5          4         100.0          ?    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %% [markdown]
# Note that we used to df to see orginal data. We can see the Nan values in df_processed because values are actually "?" in df
#
#  - Dropping the rows having NaN as horse power.

# %%
df_processed = df_processed.dropna(subset=['horsepower'])
df_processed
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# #### Training OLS Model

# %%
from sklearn.model_selection import train_test_split

X = df_processed['horsepower']
y = df_processed['mpg']
# Add a constant to the predictor variable X
X = sm.add_constant(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)



# Fit the linear regression model
model = sm.OLS(y_train, X_train).fit()

# Print the summary of the model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     527.8
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):           7.18e-72
# Time:                        17:15:47   Log-Likelihood:                -1060.9
# No. Observations:                 352   AIC:                             2126.
# Df Residuals:                     350   BIC:                             2133.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.9844      0.767     52.114      0.000      38.475      41.493
# ...

# %% [markdown]
# **Error in Model**

# %%
y_train_predicted = model.predict(X_train)
residuals = y_train - y_train_predicted
mse = np.mean(residuals**2)
print("Mean Squared Error (MSE) for training data :", mse)
y_test_predicted = model.predict(X_test)
residuals = y_test - y_test_predicted
mse = np.mean(residuals**2)
print("Mean Squared Error (MSE) for test data :", mse)
# Out:
# Mean Squared Error (MSE) for training data : 24.283283675025654
# Mean Squared Error (MSE) for test data : 20.998084626703974

# %% [markdown]
# ### i. Is there a relationship between the predictor and the response?

# %% [markdown]
# Yes, there is a relationship between the predictor (horsepower) and the response (mpg). This is indicated by the t-stastic and p-value associated with the horsepower coefficient.

# %% [markdown]
# ### ii. How strong is the relationship between the predictor and the response? Focus on the _RSE_, estimated $R^2$, and _slope._

# %% [markdown]
# The relationship between horsepower and mpg is moderately strong. The adjusted R-squared value of 0.600 suggests that approximately 60% of the variability in mpg can be explained by the linear regression model with horsepower as the predictor. The slope of the regression line is -0.1577, indicating that for every one unit increase in horsepower, mpg decreases by approximately 0.1577 units.

# %% [markdown]
# ### iii. Is the relationship between the predictor and the response positive or negative?

# %% [markdown]
# The relationship between horsepower and mpg is negative, as indicated by the negative coefficient (-0.1577)

# %% [markdown]
# ### iv. What is the predicted mpg associated with a __horsepower__ of __98__? What are the associated 95% confidence and prediction intervals?

# %%
# BEGIN SOLUTION
pred = model.get_prediction(np.array([1, 98]))
s = pred.summary_frame(alpha=0.05)
s
# END SOLUTION
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  24.531988  0.267744      24.005397      25.058578     14.798243
#
#    obs_ci_upper
# 0     34.265732

# %%
print(f"Predicted mpg for horsepower 98: {s['mean'].values[0]}")
print(f"95% Confidence Interval: [{s['mean_ci_lower'].values[0]}, {s['mean_ci_upper'].values[0]}]")
print(f"95% Prediction Interval: [{s['obs_ci_lower'].values[0]}, {s['obs_ci_upper'].values[0]}]")
# Out:
# Predicted mpg for horsepower 98: 24.531987617801335
# 95% Confidence Interval: [24.00539735248127, 25.058577883121398]
# 95% Prediction Interval: [14.79824281906022, 34.26573241654245]

# %% [markdown]
# ### V. **Now, please briefly explain the main use of inverse predictions. List at least two practical examples.**

# %% [markdown]
# Inverse prediction, also known as back prediction or prediction in the reverse direction, is a statistical method used to estimate the value of an independent variable (predictor) based on a known value of the dependent variable (response) and the regression model.
#
# The main use of inverse predictions is to estimate the value of the independent variable when only the dependent variable is known. This can be useful in various scenarios, such as:
#
# 1. Quality control: In manufacturing, if a product fails a quality test and the dependent variable (e.g., strength, durability) is known, inverse prediction can be used to estimate the value of the independent variable (e.g., temperature, pressure) that led to the failure. This information can help identify and correct the root cause of the problem.
#
# 2. Environmental monitoring: In environmental studies, if the concentration of a pollutant in a water body exceeds a certain threshold (dependent variable), inverse prediction can be used to estimate the likely source or causes of the pollution (independent variables such as emission levels, waste disposal practices) based on the regression model. This information can guide mitigation efforts and policy decisions.

# %% [markdown]
# ### vi. use " fsolve function from scipy "  (or any function of your preference) to infer horsepower from the same mpg value predicted in (__iv__). Comment on your results.
#
# Link to fsolve from scipy library:
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fsolve.html

# %%
# BEGIN SOLUTION
from scipy.optimize import fsolve

def regression_function(horsepower, const, coef, mpg):
    return const + coef * horsepower - mpg

mpg_predicted = 24.531987617801335

const = 39.9844
coef = -0.1577	


initial_guess = 10  
horsepower_inferred = fsolve(regression_function, initial_guess, args=(const, coef, mpg_predicted))[0]

print(f"Inferred horsepower for predicted mpg {mpg_predicted}: {horsepower_inferred:.2f}")

# END SOLUTION
# Out:
# Inferred horsepower for predicted mpg 24.531987617801335: 97.99

# %% [markdown]
# Predicted mpg for horsepower 98: 24.531987617801335. For the same mpg the inverse prediction give us the value 97.99. The error seems to be just 0.01. So inverse prediction also works wel for OLS model defined before.

# %% [markdown]
# ### b) Plot the response and the predictor. Use the `lmplot()` function from seaborn to display the least squares regression line.
#
# Link to lmplot() in seaborn:
#
# https://seaborn.pydata.org/archive/0.11/tutorial/regression.html#:~:text=(%22tips%22)-,Functions%20to%20draw%20linear%20regression%20models,much%20of%20their%20core%20functionality.

# %%
# BEGIN SOLUTION
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x='horsepower', y='mpg', data=df_processed, ci=None)
plt.title('Least Squares Regression Line')
plt.show()

# END SOLUTION

# %% [markdown]
# ### c) Use the `plot_fit` function from statsmodels library to produce diagnostic plots of the least squares regression fit. Comment on any problems you see with the fit.
#
# Link to plot_fit:
#
# https://www.statsmodels.org/dev/generated/statsmodels.graphics.regressionplots.plot_fit.html

# %%
# BEGIN SOLUTION
from statsmodels.graphics.regressionplots import plot_fit
plot_fit(model, 1)
plt.show()


# END SOLUTION

# %% [markdown]
# The ploat shows that
#  1. The orginal mpg values are deviating to higher value when horsepower is < 100 and > 180
#  2. The middle of the regression line is more fit when compared to ones in the beginning and end.
#  3. There is a lot of variance in data when hoursepower is less than 100. The number of observations are crowded when hoursepower is less than 100
#  4. It seems the actual relation is of second degree

# %% [markdown]
# ## Question 5

# %% [markdown]
# This question involves the use of multiple linear regression on the Auto data set. Read the dataset first:

# %% [markdown]
# ### a) Produce a scatterplot matrix using pairplot() from seaborn library which includes all of the variables in the data set
#
# Link to pairplot:
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
# BEGIN SOLUTION
import seaborn as sns
sns.pairplot(df)
# END SOLUTION
# Out:
# /Users/lngeorge/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/lngeorge/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/lngeorge/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### b) Compute the matrix of correlations between the variables using the function `corr()`in pandas on the dataframe also plot the corresponding correlation matrix using `heatmap ` function in seaborn
#
# Links:
#
# Corr() : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html
#
# Heatmap : https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
# BEGIN SOLUTION
import matplotlib.pyplot as plt
correlation_matrix = df_processed[["mpg", "cylinders","displacement", "horsepower",	"weight",	"acceleration",	"year",	"origin"]].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Correlation Matrix')
plt.show()

# END SOLUTION

# %% [markdown]
#  - The mpg shows strong negative correlation to cylinders, displacement, hoursepower and weight.The mpg is also positively correlated to acceleration, year and origin.
#  - cylinders, diplacement, hoursepower and weight seems to be very highly negatively correlated to each other.
#  - acceleration, year, and origin seems to be very weakly correlated. (positive, but weak correlation)
#  - acceleration, year, and origin are negavively correlated to cylinders, displacement, hoursepower and weight

# %% [markdown]
# ### c) Use the `ols()`  function from statsmodels library to perform a multiple linear regression with mpg as the response and all other variables except name as the predictors. Use the `summary()` function from statsmodels to print the results. Use the questions below to comment on the output.
#
# Reference to Statsmodels library and ols :
#
# https://www.statsmodels.org/dev/generated/statsmodels.regression.linear_model.OLS.html#generated-statsmodels-regression-linear-model-ols--page-root
#
# Links to summary:
#
# https://www.statsmodels.org/devel/generated/statsmodels.regression.linear_model.OLSResults.summary.html

# %%
# BEGIN SOLUTION
X = df_processed[["cylinders", "displacement", "horsepower", "weight", "acceleration", "year", "origin"]]
y = df_processed['mpg']
# Add a constant to the predictor variable X
X = sm.add_constant(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Fit the linear regression model
model = sm.OLS(y_train, X_train).fit()

# Print the summary of the model
model.summary()

# END SOLUTION
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     220.1
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):          6.35e-123
# Time:                        17:15:52   Log-Likelihood:                -923.34
# No. Observations:                 352   AIC:                             1863.
# Df Residuals:                     344   BIC:                             1894.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_train_predicted = model.predict(X_train)
residuals = y_train - y_train_predicted
mse = np.mean(residuals**2)
print("Mean Squared Error (MSE) for training data :", mse)
y_test_predicted = model.predict(X_test)
residuals = y_test - y_test_predicted
mse = np.mean(residuals**2)
print("Mean Squared Error (MSE) for test data :", mse)
# Out:
# Mean Squared Error (MSE) for training data : 11.115559949956547
# Mean Squared Error (MSE) for test data : 8.627183218870334

# %% [markdown]
# #### i. Is there a significant association between the predictors and the response?

# %% [markdown]
#  - For cylinders, the p-value is 0.231, which is greater than 0.05. This suggests that there is not a significant association between cylinders and mpg.
#
#  - For displacement, the p-value is 0.046, which is less than 0.05. This suggests that there is a significant association between displacement and mpg.
#
#  - For horsepower, the p-value is 0.293, which is greater than 0.05. This suggests that there is not a significant association between horsepower and mpg.
#
#  - For weight, the p-value is less than 0.001. This suggests that there is a significant association between weight and mpg.
#
#  - For acceleration, the p-value is 0.591, which is greater than 0.05. This suggests that there is not a significant association between acceleration and mpg.
#
#  - For year, the p-value is less than 0.001. This suggests that there is a significant association between year and mpg.
#
#  - For origin, the p-value is less than 0.001. This suggests that there is a significant association between origin and mpg.

# %% [markdown]
# #### ii. Which predictors appear to have a statistically significant relationship to the response?

# %% [markdown]
# The predictors displacement, weight, year, origin shows statistically significant relationship to the response.

# %% [markdown]
# #### iii. What does the coefficient for the year variable suggest?

# %% [markdown]
# Coefficient for the year variable is 0.7546. It suggests a positive slope(correlation) which means as time progress, the mpg is improving with time.

# %% [markdown]
# ### d) Use the `plot_fit ()` function from statsmodels to produce diagnostic plots of the linear regression fit. Again, feel free to use any other package or function to create these plots. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?
#
# Link to plot_fit:
#
# https://www.statsmodels.org/dev/generated/statsmodels.graphics.regressionplots.plot_fit.html
#
# Link to residual plots:
#
# https://www.statsmodels.org/dev/generated/statsmodels.graphics.regressionplots.plot_leverage_resid2.html

# %%
#using plot_fit()

# %%
# BEGIN SOLUTION
import matplotlib.pyplot as plt
from statsmodels.graphics.regressionplots import plot_fit

fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(16, 20))
# plot_fit(model, 1, ax=axs[0,0])
for i in range(0,8):
    plot_fit(model, i, ax=axs[int(i/2), int(i % 2)])
plt.show()

# END SOLUTION

# %%
#using plot_leverage_resid2

# %%
# BEGIN SOLUTION

from statsmodels.graphics.regressionplots import plot_leverage_resid2

# Plot the leverage-residual squared
# fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(16, 20))
# plot_fit(model, 1, ax=axs[0,0])
# for i in range(0,8):
#     plot_leverage_resid2(model, i, ax=axs[int(i/2), int(i % 2)])
# plt.show()
plot_leverage_resid2(model)
plt.show()

# END SOLUTION

# %% [markdown]
# The point marked by 13 shows a large amount of Leverage of around 0.20. For 13 index in train value, the mpg is abnoramlly low showing 36.

# %% [markdown]
# ### e) Fit a linear regression model with interaction effects. explore a few different models (~3–4 models). Do any interactions appear to be statistically significant in any of the models you examined?
#
# Use formula.ols to check the interaction between two predictors as used in the below reference link
#
# https://www.statsmodels.org/devel/example_formulas.html

# %%
# BEGIN SOLUTION
from statsmodels.formula.api import ols

model1 = ols('mpg ~ cylinders + displacement + horsepower + weight + acceleration + year + origin + year*horsepower', data=df_processed).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     274.0
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):          2.52e-153
# Time:                        17:16:55   Log-Likelihood:                -987.72
# No. Observations:                 392   AIC:                             1993.
# Df Residuals:                     383   BIC:                             2029.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model2 = ols('mpg ~ cylinders + displacement + horsepower + weight + acceleration + year + origin + year*cylinders', data=df_processed).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     249.3
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):          1.01e-146
# Time:                        17:18:09   Log-Likelihood:                -1003.3
# No. Observations:                 392   AIC:                             2025.
# Df Residuals:                     383   BIC:                             2060.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Fit a model with interaction between 'horsepower' and 'year'
model3 = ols('mpg ~ cylinders + displacement + horsepower + weight + acceleration + year + origin + horsepower:origin', data=df_processed).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     274.0
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):          2.52e-153
# Time:                        17:15:53   Log-Likelihood:                -987.72
# No. Observations:                 392   AIC:                             1993.
# Df Residuals:                     383   BIC:                             2029.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -97.2279     10.077     -9.648      0.000    -117.041     -77.414
# ...

# %% [markdown]
# These are the results of four different OLS (Ordinary Least Squares) regression models. Each model attempts to predict the miles per gallon (`mpg`) of a car based on various features. Here is a brief summary of each model:
#
# 1. Model 1:
#    - Features: cylinders, displacement, horsepower, weight, acceleration, year, origin, year:horsepower
#    - R-squared: 0.851
#    - Notable coefficients: horsepower (0.8070), weight (-0.0053), year (1.8298), origin (1.1776), year:horsepower (-0.0114)
#
# 2. Model 2:
#    - Features: cylinders, displacement, horsepower, weight, acceleration, year, origin, year:cylinders
#    - R-squared: 0.839
#    - Notable coefficients: cylinders (14.6890), weight (-0.0062), year (1.7336), origin (1.3754), year:cylinders (-0.1949)
#
# 3. Model 3:
#    - Features: cylinders, displacement, horsepower, weight, acceleration, year, origin, horsepower:origin
#    - R-squared: 0.844
#    - Notable coefficients: horsepower (0.0817), weight (-0.0047), year (0.7327), origin (7.6953), horsepower:origin (-0.0796)
#
# 4. Model 4:
#    - Features: cylinders, displacement, horsepower, weight, acceleration, year, origin, horsepower:cylinders
#    - R-squared: 0.862
#    - Notable coefficients: cylinders (-4.3061), horsepower (-0.3157), weight (-0.0039), year (0.7393), origin (0.9032), horsepower:cylinders (0.0402)
#
# Each model's R-squared value indicates how well the model fits the data, with higher values indicating a better fit. The coefficients for each feature indicate the strength and direction of their relationship with the target variable (`mpg`).

# %% [markdown]
# ### f) Try a few different transformations of the variables, such as `log(X)`, `sqrt(X)`, $X^2$. Comment on your findings.

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# ## Question 6

# %% [markdown]
# In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use `set.seed(1)` prior to starting part (a) to ensure consistent results.

# %% [markdown]
# ### a) Using the random normal function, create a vector, `x`, containing 100 observations drawn from a $N(0, 1)$ distribution. This represents a feature, `X`.
#
# Link to random normal function:
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# ### b) Using the `random normal` function, create a vector, `eps`, containing 100 observations drawn from a $N(0, 0.25)$ distribution — a normal distribution with mean zero and variance `0.25`.
#
# Link to random normal function:
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# ### c) Using `x` and `eps`, generate a vector `y` according to the model $Y = -1 + 0.5X + ϵ$. What is the length of the vector `y`? What are the values of $β_0$ and $β_1$ in this linear model?

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### d) Create a scatterplot displaying the relationship between `x` and `y`. Comment on what you observe.

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### e) Fit a least squares linear model that relates y and `x`. Comment on the model obtained. How do the estimated coefficients (slope and intercept) compare to the true values used to simulate the data?

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### f) Display the least squares line on the scatterplot obtained in (d). Draw the estimated regression line on the plot, in a different color.  Feel free to use  any framework such as ggplot or matplotlib, seaborn etc

# %%
# BEGIN SOLUTION

# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### g) Now fit a polynomial regression model that predicts $y$ using $x$ and $x^2$. Is there evidence that the quadratic term improves the model fit? Explain your answer.

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### h) Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model analyzed in this section,, should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term ϵ in (b). Describe your results.

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### i) Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model analyzed in this section ($Y = -1 + 0.5X + ϵ$) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term $ϵ$ in (b). Describe your results.

# %%
# BEGIN SOLUTION


# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ### j) What are the confidence intervals for $β_0$ and $β_1$ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## Question 7

# %% [markdown]
# This question focuses on the collinearity problem

# %% [markdown]
# ## (a) Perform the following commands in `Python`

# %%
import numpy as np

np.random.seed(1)

x1 = np.random.uniform(size=100)

x2 = 0.5 * x1 + np.random.normal(size=100) / 10

y = 2 + 2 * x1 + 0.3 * x2 + np.random.normal(size=100)

# %% [markdown]
# The last line corresponds to creating a linear model in which $y$ is a function of $x_1$ and $x_2$. Write out the form of the linear model. What are the regression coefficients?

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## (b) What is the correlation between $x_1$ and $x_2$? Create a scatterplot displaying the relationship between the variables.
#
#
# link to correlation function: https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html

# %%
# BEGIN SOLUTION

# END SOLUTION

# %% [markdown]
# ## (c) Using this data, fit a least squares regression to predict $y$ using $x_1$ and $x_2$. Describe the results obtained. What are $β_0$, $β_1$, and $β_2$? How do these relate to the true $β_0$, $β_1$, and $β_2$? Can you reject the null hypothesis $H_0$: $β_1$ = 0? How about the null hypothesis $H_0$: $β_2$ = 0?

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## (d) Now fit a least squares regression to predict $y$ using only $x_1$. Comment on your results. Can you reject the null hypothesis $H_0$: $β_1$ = 0?

# %%
# BEGIN SOLUTION



# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## (e) Now fit a least squares regression to predict $y$ using only $x_2$. Comment on your results. Can you reject the null hypothesis $H_0$: $β_1$ = 0?

# %%
# BEGIN SOLUTION

# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## (f) Do the results obtained in (c)–(e) contradict each other? Explain your answer.

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## (g) Now suppose we obtain one additional observation, which was unfortunately mismeasured. Re-fit the linear models from (c) to (e) using this new data. What effect does this new observation have on each of the models? In each model, is this observation an outlier? A high-leverage point? Both? Explain your answers.

# %%
# BEGIN SOLUTION

# END SOLUTION

# %% [markdown]
# Provide you comments / answer here

# %% [markdown]
# ## Question 8

# %% [markdown]
# It is claimed that in the case of simple linear regression of $Y$ onto $X$, the $R^2$ statistic is equal to the square of the correlation between $X$ and $Y$. Generate some synthetic data and show that this is the case.
#
# link to  correlation function:
# https://numpy.org/doc/stable/reference/generated/numpy.corrcoef.html

# %%
# BEGIN SOLUTION

# END SOLUTION
